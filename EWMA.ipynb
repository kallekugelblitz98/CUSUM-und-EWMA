# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from matplotlib.figure import Figure


data = np.array([0,31.6, 27.9, 32.1, 29.2, 30.1, 28.2, 30.9, 30.3, 31.2, 30.3, 29.4, 27.8, 29.9, 31.2, 32.5, 31.2, 32.6, 32.4, 33.6, 31.2])
df = pd.DataFrame(data, columns=["Werte"])

mu = 30
alpha = 0.3
L = 3
sigma = 2.13

# UCL und LCL berechnen
ucl = mu + L * sigma * np.sqrt(alpha / (2 - alpha))
lcl = mu - L * sigma * np.sqrt(alpha / (2 - alpha))


df['EWMA(Zi)'] = 0
df.loc[0, 'EWMA(Zi)'] = mu
df['LambdaXi'] = 0
df['(1-lambda)Zi-1'] = 0
df['UCL'] = 0
df['LCL'] = 0

# EWMA-Werte berechnen
for i in range(1, len(df)):
    df.loc[i, 'EWMA(Zi)'] = (alpha * df.loc[i, 'Werte']) + ((1 - alpha) * df.loc[i-1, 'EWMA(Zi)'])
    df.loc[i, 'LambdaXi'] = (0.3 * df.loc[i, 'Werte'])
    df.loc[i, '(1-lambda)Zi-1'] = ((1 - 0.3) * df.loc[i-1, 'EWMA(Zi)'])



plt.figure(figsize=(12, 6))
plt.plot(df.index, df['EWMA(Zi)'], label='EWMA(Zi)', color='blue')
#plt.plot(df.index, df['Werte'], label='Werte', color='red', linestyle='--')
plt.axhline(y=mu, color='black', linestyle='-', label='Target (µ=30)')
plt.axhline(y=ucl, color='green', linestyle='--', label=f'UCL = {ucl:.3f}')
plt.axhline(y=lcl, color='purple', linestyle='--', label=f'LCL = {lcl:.3f}')
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('EWMA Chart with Control Limits')
plt.legend()
plt.grid(True)
plt.savefig("ewma_plot.jpeg", format='jpeg')
plt.show()
df
# Out:
#     Werte   EWMA(Zi)  LambdaXi  (1-lambda)Zi-1  UCL  LCL
# 0     0.0  30.000000      0.00        0.000000    0    0
# 1    31.6  30.480000      9.48       21.000000    0    0
# 2    27.9  29.706000      8.37       21.336000    0    0
# 3    32.1  30.424200      9.63       20.794200    0    0
# 4    29.2  30.056940      8.76       21.296940    0    0
# 5    30.1  30.069858      9.03       21.039858    0    0
# 6    28.2  29.508901      8.46       21.048901    0    0
# 7    30.9  29.926230      9.27       20.656230    0    0
# 8    30.3  30.038361      9.09       20.948361    0    0
# 9    31.2  30.386853      9.36       21.026853    0    0
# 10   30.3  30.360797      9.09       21.270797    0    0
# 11   29.4  30.072558      8.82       21.252558    0    0
# 12   27.8  29.390791      8.34       21.050791    0    0
# 13   29.9  29.543553      8.97       20.573553    0    0
# 14   31.2  30.040487      9.36       20.680487    0    0
# 15   32.5  30.778341      9.75       21.028341    0    0
# 16   31.2  30.904839      9.36       21.544839    0    0
# 17   32.6  31.413387      9.78       21.633387    0    0
# 18   32.4  31.709371      9.72       21.989371    0    0
# 19   33.6  32.276560     10.08       22.196560    0    0
# 20   31.2  31.953592      9.36       22.593592    0    0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Daten definieren
data = np.array([0,31.6, 27.9, 32.1, 29.2, 30.1, 28.2, 30.9, 30.3, 31.2, 30.3, 29.4, 27.8, 29.9, 31.2, 32.5, 31.2, 32.6, 32.4, 33.6, 31.2])

df = pd.DataFrame(data, columns=["Werte"])

# Initialwert und Parameter
mu = 30
alpha = 0.3
L = 3
sigma = 2.13

# EWMA initialisieren
df['EWMA(Zi)'] = 0
df.loc[0, 'EWMA(Zi)'] = mu 
df['UCL'] = mu + 1
df['LCL'] = mu - 1

df['LambdaXi'] = 0
df['(1-lambda)Zi-1'] = 0


# EWMA-Werte und dynamische Kontrollgrenzen berechnen
for i in range(1, len(df)):
    df.loc[i, 'EWMA(Zi)'] = (alpha * df.loc[i, 'Werte']) + ((1 - alpha) * df.loc[i-1, 'EWMA(Zi)'])
    df.loc[i, 'LambdaXi'] = (0.3 * df.loc[i, 'Werte'])
    df.loc[i, '(1-lambda)Zi-1'] = ((1 - 0.3) * df.loc[i-1, 'EWMA(Zi)'])
    dynamic_sigma = sigma * np.sqrt(alpha / (2 - alpha) * (1 - (1 - alpha)**(2 * i)))
    df.loc[i, 'UCL'] = mu + L * dynamic_sigma
    df.loc[i, 'LCL'] = mu - L * dynamic_sigma
    



# Plot erstellen und speichern
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['EWMA(Zi)'], label='EWMA(Zi)', color='blue')
#plt.plot(df.index, df['Werte'], label='Werte', color='red', linestyle='--')
plt.plot(df.index, df['UCL'], label='UCL', color='green', linestyle='--')
plt.plot(df.index, df['LCL'], label='LCL', color='purple', linestyle='--')
plt.axhline(y=mu, color='black', linestyle='-', label='Target (µ=30)')
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('EWMA Chart with Dynamic Control Limits')
plt.legend()
plt.grid(True)

# Plot als Bild speichern
plt.savefig("ewma_plot.jpeg", format='jpeg')

plt.show()

# DataFrame anzeigen
df
# Out:
#     Werte   EWMA(Zi)        UCL        LCL  LambdaXi  (1-lambda)Zi-1
# 0     0.0  30.000000  31.000000  29.000000      0.00        0.000000
# 1    31.6  30.480000  31.917000  28.083000      9.48       21.000000
# 2    27.9  29.706000  32.339997  27.660003      8.37       21.336000
# 3    32.1  30.424200  32.521493  27.478507      9.63       20.794200
# 4    29.2  30.056940  32.605815  27.394185      8.76       21.296940
# 5    30.1  30.069858  32.646152  27.353848      9.03       21.039858
# 6    28.2  29.508901  32.665695  27.334305      8.46       21.048901
# 7    30.9  29.926230  32.675219  27.324781      9.27       20.656230
# 8    30.3  30.038361  32.679873  27.320127      9.09       20.948361
# 9    31.2  30.386853  32.682150  27.317850      9.36       21.026853
# 10   30.3  30.360797  32.683266  27.316734      9.09       21.270797
# 11   29.4  30.072558  32.683812  27.316188      8.82       21.252558
# 12   27.8  29.390791  32.684080  27.315920      8.34       21.050791
# 13   29.9  29.543553  32.684211  27.315789      8.97       20.573553
# 14   31.2  30.040487  32.684275  27.315725      9.36       20.680487
# 15   32.5  30.778341  32.684307  27.315693      9.75       21.028341
# 16   31.2  30.904839  32.684322  27.315678      9.36       21.544839
# 17   32.6  31.413387  32.684330  27.315670      9.78       21.633387
# 18   32.4  31.709371  32.684333  27.315667      9.72       21.989371
# 19   33.6  32.276560  32.684335  27.315665     10.08       22.196560
# 20   31.2  31.953592  32.684336  27.315664      9.36       22.593592
